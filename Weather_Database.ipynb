# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = list()

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


# Print the city count to confirm sufficient count
print(cities[:10], 'Generate', len(cities))
# Out:
# ['novyy urengoy', 'kapaa', 'avarua', 'araouane', 'nisia floresta', 'jamestown', 'barrow', 'codrington', 'ushuaia', 'saint george'] Generate 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i >= 50 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining fall
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing fall
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | novyy urengoy
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | araouane
# Processing Record 5 of Set 1 | nisia floresta
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | codrington
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | bathsheba
# Processing Record 14 of Set 1 | vao
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | rincon
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | arzamas
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | ereymentau
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | bilma
# Processing Record 25 of Set 1 | poniatowa
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | finschhafen
# Processing Record 28 of Set 1 | syamzha
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | mpulungu
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | dubai
# Processing Record 38 of Set 1 | arman
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | varna
# Processing Record 44 of Set 1 | la ronge
# Processing Record 45 of Set 1 | luderitz
# Processing Record 46 of Set 1 | wawa
# Processing Record 47 of Set 1 | carauari
# Processing Record 48 of Set 1 | vicuna
# Processing Record 49 of Set 1 | semey
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | honningsvag
# Processing Record 7 of Set 2 | azare
# Processing Record 8 of Set 2 | hutchinson
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | sao gabriel da cachoeira
# Processing Record 11 of Set 2 | san diego de la union
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | ahipara
# Processing Record 14 of Set 2 | fortuna
# Processing Record 15 of Set 2 | shelburne
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | muros
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | elwood
# Processing Record 20 of Set 2 | kimbe
# Processing Record 21 of Set 2 | la cruz
# Processing Record 22 of Set 2 | andilamena
# Processing Record 23 of Set 2 | biograd na moru
# Processing Record 24 of Set 2 | muli
# Processing Record 25 of Set 2 | ozernovskiy
# Processing Record 26 of Set 2 | alice springs
# Processing Record 27 of Set 2 | quatre cocos
# Processing Record 28 of Set 2 | dibaya
# City not found. Skipping...
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 2 | bayji
# Processing Record 33 of Set 2 | raudeberg
# Processing Record 34 of Set 2 | qui nhon
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | arcata
# Processing Record 37 of Set 2 | leh
# Processing Record 38 of Set 2 | guerrero negro
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | undory
# Processing Record 43 of Set 2 | bougouni
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | coolum beach
# Processing Record 46 of Set 2 | aykhal
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | swift current
# Processing Record 49 of Set 2 | wynyard
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | morant bay
# Processing Record 3 of Set 3 | kumluca
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | juneau
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | fontenay-le-comte
# Processing Record 9 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | dayong
# Processing Record 13 of Set 3 | nishihara
# Processing Record 14 of Set 3 | roald
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | agadez
# Processing Record 18 of Set 3 | mulki
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | coihaique
# Processing Record 21 of Set 3 | sioux lookout
# Processing Record 22 of Set 3 | moron
# Processing Record 23 of Set 3 | ahmadpur east
# Processing Record 24 of Set 3 | ponnani
# Processing Record 25 of Set 3 | kalabo
# Processing Record 26 of Set 3 | piranhas
# Processing Record 27 of Set 3 | west fargo
# Processing Record 28 of Set 3 | kargasok
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 33 of Set 3 | kununurra
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | somerset
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | laguna
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | el vigia
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | tsiroanomandidy
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | rockhampton
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | bhongir
# Processing Record 47 of Set 3 | yagoua
# Processing Record 48 of Set 3 | okhotsk
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | santa marta
# Processing Record 2 of Set 4 | fort morgan
# Processing Record 3 of Set 4 | porto santo
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | aklavik
# Processing Record 6 of Set 4 | hobart
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | lacolle
# Processing Record 9 of Set 4 | kamalpur
# Processing Record 10 of Set 4 | esperance
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 4 | victoria
# Processing Record 15 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | ribas do rio pardo
# Processing Record 18 of Set 4 | nouadhibou
# Processing Record 19 of Set 4 | yar-sale
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | maues
# Processing Record 22 of Set 4 | gharghoda
# Processing Record 23 of Set 4 | huilong
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | sao sebastiao
# Processing Record 26 of Set 4 | paris
# Processing Record 27 of Set 4 | paamiut
# Processing Record 28 of Set 4 | kavieng
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | acapulco
# Processing Record 31 of Set 4 | chunskiy
# Processing Record 32 of Set 4 | mtwara
# Processing Record 33 of Set 4 | aktash
# Processing Record 34 of Set 4 | aksu
# Processing Record 35 of Set 4 | yangjiang
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | bluff
# Processing Record 38 of Set 4 | bijie
# Processing Record 39 of Set 4 | porto novo
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | verkhnyaya inta
# Processing Record 42 of Set 4 | woodward
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | kalianget
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | saint anthony
# Processing Record 47 of Set 4 | yellowknife
# Processing Record 48 of Set 4 | urumqi
# Processing Record 49 of Set 4 | pocao de pedras
# Processing Record 50 of Set 4 | kazbegi
# City not found. Skipping...
# Processing Record 1 of Set 5 | rio grande
# Processing Record 2 of Set 5 | praia da vitoria
# Processing Record 3 of Set 5 | taoudenni
# Processing Record 4 of Set 5 | rawson
# Processing Record 5 of Set 5 | ubinskoye
# Processing Record 6 of Set 5 | bairiki
# Processing Record 7 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 5 | esqueda
# Processing Record 9 of Set 5 | shingu
# Processing Record 10 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 5 | san patricio
# Processing Record 12 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 5 | tayibe
# City not found. Skipping...
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | komsomolskiy
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | tornio
# Processing Record 18 of Set 5 | kloulklubed
# Processing Record 19 of Set 5 | derzhavinsk
# Processing Record 20 of Set 5 | constantine
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | nouakchott
# Processing Record 23 of Set 5 | kalaswala
# Processing Record 24 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | haines junction
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | luena
# Processing Record 29 of Set 5 | sehore
# Processing Record 30 of Set 5 | merauke
# Processing Record 31 of Set 5 | baiao
# Processing Record 32 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 5 | vanavara
# Processing Record 34 of Set 5 | barinas
# Processing Record 35 of Set 5 | aksarka
# Processing Record 36 of Set 5 | meulaboh
# Processing Record 37 of Set 5 | chiredzi
# Processing Record 38 of Set 5 | tabas
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | ilulissat
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | methoni
# Processing Record 43 of Set 5 | sao joao da barra
# Processing Record 44 of Set 5 | dingle
# Processing Record 45 of Set 5 | kamra
# Processing Record 46 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 5 | kirakira
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | upernavik
# Processing Record 50 of Set 5 | andijon
# Processing Record 1 of Set 6 | assiniboia
# Processing Record 2 of Set 6 | paita
# Processing Record 3 of Set 6 | esna
# Processing Record 4 of Set 6 | callaguip
# Processing Record 5 of Set 6 | miandrivazo
# Processing Record 6 of Set 6 | kologriv
# Processing Record 7 of Set 6 | tomar
# Processing Record 8 of Set 6 | joaima
# Processing Record 9 of Set 6 | faanui
# Processing Record 10 of Set 6 | hay river
# Processing Record 11 of Set 6 | havoysund
# Processing Record 12 of Set 6 | sretensk
# Processing Record 13 of Set 6 | golden
# Processing Record 14 of Set 6 | santa cruz del sur
# Processing Record 15 of Set 6 | springfield
# Processing Record 16 of Set 6 | havelock
# Processing Record 17 of Set 6 | kabo
# Processing Record 18 of Set 6 | buala
# Processing Record 19 of Set 6 | avera
# Processing Record 20 of Set 6 | pontes e lacerda
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | maridi
# Processing Record 25 of Set 6 | teya
# Processing Record 26 of Set 6 | salalah
# Processing Record 27 of Set 6 | diamantino
# Processing Record 28 of Set 6 | arlit
# Processing Record 29 of Set 6 | tenosique
# Processing Record 30 of Set 6 | hofn
# Processing Record 31 of Set 6 | coquimbo
# Processing Record 32 of Set 6 | zaraza
# Processing Record 33 of Set 6 | manggar
# Processing Record 34 of Set 6 | nizza monferrato
# Processing Record 35 of Set 6 | valparaiso
# Processing Record 36 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 6 | barra patuca
# Processing Record 38 of Set 6 | aleysk
# Processing Record 39 of Set 6 | washim
# Processing Record 40 of Set 6 | mayo
# Processing Record 41 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 6 | northam
# Processing Record 43 of Set 6 | torbay
# Processing Record 44 of Set 6 | jucas
# Processing Record 45 of Set 6 | tooele
# Processing Record 46 of Set 6 | samarai
# Processing Record 47 of Set 6 | dahuk
# Processing Record 48 of Set 6 | sao filipe
# Processing Record 49 of Set 6 | dengzhou
# Processing Record 50 of Set 6 | oranjemund
# Processing Record 1 of Set 7 | santa isabel do rio negro
# Processing Record 2 of Set 7 | loudi
# Processing Record 3 of Set 7 | sayansk
# Processing Record 4 of Set 7 | la crosse
# Processing Record 5 of Set 7 | punta alta
# Processing Record 6 of Set 7 | konevo
# Processing Record 7 of Set 7 | bismarck
# Processing Record 8 of Set 7 | hervey bay
# Processing Record 9 of Set 7 | riyadh
# Processing Record 10 of Set 7 | marawi
# Processing Record 11 of Set 7 | fort nelson
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | shibarghan
# City not found. Skipping...
# Processing Record 14 of Set 7 | dandong
# Processing Record 15 of Set 7 | caravelas
# Processing Record 16 of Set 7 | zyryanovsk
# Processing Record 17 of Set 7 | morgantown
# Processing Record 18 of Set 7 | kachug
# Processing Record 19 of Set 7 | kpagouda
# City not found. Skipping...
# Processing Record 20 of Set 7 | turukhansk
# Processing Record 21 of Set 7 | lepe
# Processing Record 22 of Set 7 | sarangani
# Processing Record 23 of Set 7 | keti bandar
# Processing Record 24 of Set 7 | panjakent
# Processing Record 25 of Set 7 | san nicolas
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | goderich
# Processing Record 28 of Set 7 | vallenar
# Processing Record 29 of Set 7 | burgersdorp
# Processing Record 30 of Set 7 | kavaratti
# Processing Record 31 of Set 7 | palmerston
# Processing Record 32 of Set 7 | rzhyshchiv
# Processing Record 33 of Set 7 | jacareacanga
# Processing Record 34 of Set 7 | polson
# Processing Record 35 of Set 7 | russell
# Processing Record 36 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 7 | kharp
# Processing Record 38 of Set 7 | vega de alatorre
# Processing Record 39 of Set 7 | kalakamati
# Processing Record 40 of Set 7 | port macquarie
# Processing Record 41 of Set 7 | naryan-mar
# Processing Record 42 of Set 7 | port arthur
# Processing Record 43 of Set 7 | butajira
# Processing Record 44 of Set 7 | dwarka
# Processing Record 45 of Set 7 | diego de almagro
# Processing Record 46 of Set 7 | kuytun
# Processing Record 47 of Set 7 | tela
# Processing Record 48 of Set 7 | marquette
# Processing Record 49 of Set 7 | teahupoo
# Processing Record 50 of Set 7 | changde
# Processing Record 1 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 8 | barddhaman
# Processing Record 3 of Set 8 | udachnyy
# Processing Record 4 of Set 8 | cabo san lucas
# Processing Record 5 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 8 | arcelia
# Processing Record 7 of Set 8 | grand-lahou
# Processing Record 8 of Set 8 | gayny
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | araxa
# Processing Record 11 of Set 8 | santiago
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | hutang
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | aves
# Processing Record 16 of Set 8 | san vicente
# Processing Record 17 of Set 8 | shahr-e babak
# Processing Record 18 of Set 8 | akdepe
# Processing Record 19 of Set 8 | port pirie
# Processing Record 20 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 8 | utete
# Processing Record 22 of Set 8 | roebourne
# Processing Record 23 of Set 8 | sharan
# Processing Record 24 of Set 8 | puerto quijarro
# Processing Record 25 of Set 8 | calamar
# Processing Record 26 of Set 8 | kalmunai
# Processing Record 27 of Set 8 | worcester
# Processing Record 28 of Set 8 | gornopravdinsk
# Processing Record 29 of Set 8 | palana
# Processing Record 30 of Set 8 | bethel
# Processing Record 31 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | flinders
# Processing Record 34 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 8 | tonj
# Processing Record 37 of Set 8 | stephenville
# Processing Record 38 of Set 8 | cidreira
# Processing Record 39 of Set 8 | chifeng
# Processing Record 40 of Set 8 | tura
# Processing Record 41 of Set 8 | luganville
# Processing Record 42 of Set 8 | sheregesh
# Processing Record 43 of Set 8 | prieska
# Processing Record 44 of Set 8 | leer
# Processing Record 45 of Set 8 | zhanaozen
# Processing Record 46 of Set 8 | fare
# Processing Record 47 of Set 8 | forecariah
# Processing Record 48 of Set 8 | bandarbeyla
# Processing Record 49 of Set 8 | marzuq
# Processing Record 50 of Set 8 | hasaki
# Processing Record 1 of Set 9 | belmonte
# Processing Record 2 of Set 9 | ishinomaki
# Processing Record 3 of Set 9 | erhlin
# City not found. Skipping...
# Processing Record 4 of Set 9 | vancouver
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | san pedro de ycuamandiyu
# Processing Record 7 of Set 9 | uruzgan
# Processing Record 8 of Set 9 | faya
# Processing Record 9 of Set 9 | namatanai
# Processing Record 10 of Set 9 | grindavik
# Processing Record 11 of Set 9 | belaya gora
# Processing Record 12 of Set 9 | vatne
# Processing Record 13 of Set 9 | moree
# Processing Record 14 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 15 of Set 9 | ust-kuyga
# Processing Record 16 of Set 9 | cabedelo
# Processing Record 17 of Set 9 | vostok
# Processing Record 18 of Set 9 | hluti
# Processing Record 19 of Set 9 | talnakh
# Processing Record 20 of Set 9 | geraldton
# Processing Record 21 of Set 9 | pasighat
# Processing Record 22 of Set 9 | ovalle
# Processing Record 23 of Set 9 | acarau
# Processing Record 24 of Set 9 | buchanan
# Processing Record 25 of Set 9 | luau
# Processing Record 26 of Set 9 | camacha
# Processing Record 27 of Set 9 | balabac
# Processing Record 28 of Set 9 | comodoro rivadavia
# Processing Record 29 of Set 9 | sao miguel do araguaia
# Processing Record 30 of Set 9 | wanning
# Processing Record 31 of Set 9 | monte alegre
# Processing Record 32 of Set 9 | beyneu
# Processing Record 33 of Set 9 | kutum
# Processing Record 34 of Set 9 | kaka
# Processing Record 35 of Set 9 | somanda
# Processing Record 36 of Set 9 | sola
# Processing Record 37 of Set 9 | lucapa
# Processing Record 38 of Set 9 | torrington
# Processing Record 39 of Set 9 | aloleng
# Processing Record 40 of Set 9 | arusha
# Processing Record 41 of Set 9 | palmer
# Processing Record 42 of Set 9 | lavrentiya
# Processing Record 43 of Set 9 | pisco
# Processing Record 44 of Set 9 | obihiro
# Processing Record 45 of Set 9 | nichinan
# Processing Record 46 of Set 9 | zaozerne
# Processing Record 47 of Set 9 | korla
# Processing Record 48 of Set 9 | mantua
# Processing Record 49 of Set 9 | angoche
# Processing Record 50 of Set 9 | los llanos de aridane
# Processing Record 1 of Set 10 | ola
# Processing Record 2 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | port hawkesbury
# Processing Record 5 of Set 10 | manicore
# Processing Record 6 of Set 10 | opotiki
# Processing Record 7 of Set 10 | nuuk
# Processing Record 8 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 10 | mount gambier
# Processing Record 10 of Set 10 | jumla
# Processing Record 11 of Set 10 | nsanje
# Processing Record 12 of Set 10 | saint-joseph
# Processing Record 13 of Set 10 | gao
# Processing Record 14 of Set 10 | hesperia
# Processing Record 15 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 10 | gizo
# Processing Record 17 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 10 | inongo
# Processing Record 19 of Set 10 | gondanglegi
# Processing Record 20 of Set 10 | toulepleu
# City not found. Skipping...
# Processing Record 21 of Set 10 | kuusamo
# Processing Record 22 of Set 10 | sangareddi
# Processing Record 23 of Set 10 | jos
# Processing Record 24 of Set 10 | ambilobe
# Processing Record 25 of Set 10 | genhe
# Processing Record 26 of Set 10 | sattur
# Processing Record 27 of Set 10 | richmond
# Processing Record 28 of Set 10 | nizhniy kuranakh
# Processing Record 29 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 10 | chacabuco
# Processing Record 31 of Set 10 | mount isa
# Processing Record 32 of Set 10 | usinsk
# Processing Record 33 of Set 10 | kudahuvadhoo
# Processing Record 34 of Set 10 | alta floresta
# Processing Record 35 of Set 10 | ixtapa
# Processing Record 36 of Set 10 | belokurikha
# Processing Record 37 of Set 10 | is
# City not found. Skipping...
# Processing Record 38 of Set 10 | batemans bay
# Processing Record 39 of Set 10 | puerto ayacucho
# Processing Record 40 of Set 10 | anadyr
# Processing Record 41 of Set 10 | whitehaven
# Processing Record 42 of Set 10 | batagay
# Processing Record 43 of Set 10 | ust-nera
# Processing Record 44 of Set 10 | antofagasta
# Processing Record 45 of Set 10 | leningradskiy
# Processing Record 46 of Set 10 | asau
# Processing Record 47 of Set 10 | kinkala
# Processing Record 48 of Set 10 | hurup
# Processing Record 49 of Set 10 | karasburg
# Processing Record 50 of Set 10 | puerto escondido
# Processing Record 1 of Set 11 | nhulunbuy
# Processing Record 2 of Set 11 | margate
# Processing Record 3 of Set 11 | norre alslev
# Processing Record 4 of Set 11 | salihorsk
# Processing Record 5 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 6 of Set 11 | dargaville
# Processing Record 7 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 8 of Set 11 | haapiti
# Processing Record 9 of Set 11 | biak
# Processing Record 10 of Set 11 | apartado
# Processing Record 11 of Set 11 | salinopolis
# Processing Record 12 of Set 11 | mvuma
# Processing Record 13 of Set 11 | molchanovo
# Processing Record 14 of Set 11 | nelson bay
# Processing Record 15 of Set 11 | iquique
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 18 of Set 11 | ayan
# Processing Record 19 of Set 11 | ossora
# Processing Record 20 of Set 11 | agliana
# Processing Record 21 of Set 11 | scarborough
# Processing Record 22 of Set 11 | katsuura
# Processing Record 23 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 11 | santa cruz de la palma
# Processing Record 25 of Set 11 | naze
# Processing Record 26 of Set 11 | kita
# Processing Record 27 of Set 11 | aquin
# Processing Record 28 of Set 11 | san cristobal
# Processing Record 29 of Set 11 | nakur
# Processing Record 30 of Set 11 | birao
# Processing Record 31 of Set 11 | memmingen
# Processing Record 32 of Set 11 | clyde river
# Processing Record 33 of Set 11 | dhidhdhoo
# Processing Record 34 of Set 11 | pahrump
# Processing Record 35 of Set 11 | port keats
# Processing Record 36 of Set 11 | sale
# Processing Record 37 of Set 11 | san jose
# Processing Record 38 of Set 11 | ginda
# Processing Record 39 of Set 11 | trelew
# Processing Record 40 of Set 11 | pangnirtung
# Processing Record 41 of Set 11 | pochutla
# Processing Record 42 of Set 11 | viedma
# Processing Record 43 of Set 11 | cayenne
# Processing Record 44 of Set 11 | anuchino
# Processing Record 45 of Set 11 | coahuayana
# Processing Record 46 of Set 11 | auki
# Processing Record 47 of Set 11 | richards bay
# Processing Record 48 of Set 11 | havre-saint-pierre
# Processing Record 49 of Set 11 | kamennomostskiy
# Processing Record 50 of Set 11 | atar
# Processing Record 1 of Set 12 | alyangula
# Processing Record 2 of Set 12 | terenos
# Processing Record 3 of Set 12 | gobabis
# Processing Record 4 of Set 12 | kamaishi
# Processing Record 5 of Set 12 | kuching
# Processing Record 6 of Set 12 | bria
# Processing Record 7 of Set 12 | wanaka
# Processing Record 8 of Set 12 | novovarshavka
# Processing Record 9 of Set 12 | ngunguru
# Processing Record 10 of Set 12 | te anau
# Processing Record 11 of Set 12 | zyryanka
# Processing Record 12 of Set 12 | sechura
# Processing Record 13 of Set 12 | ierapetra
# Processing Record 14 of Set 12 | ferrol
# Processing Record 15 of Set 12 | koumra
# Processing Record 16 of Set 12 | barberton
# Processing Record 17 of Set 12 | makakilo city
# Processing Record 18 of Set 12 | haimen
# Processing Record 19 of Set 12 | mezhgorye
# Processing Record 20 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 12 | syriam
# Processing Record 22 of Set 12 | maniitsoq
# Processing Record 23 of Set 12 | biltine
# Processing Record 24 of Set 12 | kidal
# Processing Record 25 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 26 of Set 12 | wanxian
# Processing Record 27 of Set 12 | sur
# Processing Record 28 of Set 12 | qandala
# Processing Record 29 of Set 12 | canete
# Processing Record 30 of Set 12 | provost
# Processing Record 31 of Set 12 | mahanoro
# Processing Record 32 of Set 12 | mirina
# City not found. Skipping...
# Processing Record 33 of Set 12 | huarmey
# Processing Record 34 of Set 12 | ciudad bolivar
# Processing Record 35 of Set 12 | muisne
# Processing Record 36 of Set 12 | yerbogachen
# Processing Record 37 of Set 12 | ternate
# Processing Record 38 of Set 12 | hwange
# Processing Record 39 of Set 12 | sobolevo
# Processing Record 40 of Set 12 | xinyu
# Processing Record 41 of Set 12 | port blair
# Processing Record 42 of Set 12 | souillac
# Processing Record 43 of Set 12 | gelgaudiskis
# Processing Record 44 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 12 | grand gaube
# Processing Record 46 of Set 12 | tabuk
# Processing Record 47 of Set 12 | pokanayevka
# City not found. Skipping...
# Processing Record 48 of Set 12 | ryotsu
# Processing Record 49 of Set 12 | acajutla
# Processing Record 50 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 13 | lasa
# Processing Record 2 of Set 13 | astipalaia
# City not found. Skipping...
# Processing Record 3 of Set 13 | kaili
# Processing Record 4 of Set 13 | stornoway
# Processing Record 5 of Set 13 | saint-georges
# Processing Record 6 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 13 | choix
# Processing Record 8 of Set 13 | meadow lake
# Processing Record 9 of Set 13 | cravo norte
# Processing Record 10 of Set 13 | koumac
# Processing Record 11 of Set 13 | batagay-alyta
# Processing Record 12 of Set 13 | noumea
# Processing Record 13 of Set 13 | dunedin
# Processing Record 14 of Set 13 | laterza
# Processing Record 15 of Set 13 | gat
# Processing Record 16 of Set 13 | najran
# Processing Record 17 of Set 13 | tres arroyos
# Processing Record 18 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 13 | ankang
# Processing Record 20 of Set 13 | ivot
# Processing Record 21 of Set 13 | honiara
# Processing Record 22 of Set 13 | bobrovytsya
# Processing Record 23 of Set 13 | lleida
# Processing Record 24 of Set 13 | cockburn town
# Processing Record 25 of Set 13 | wasilla
# Processing Record 26 of Set 13 | zalantun
# Processing Record 27 of Set 13 | astrea
# Processing Record 28 of Set 13 | huangmei
# Processing Record 29 of Set 13 | innisfail
# Processing Record 30 of Set 13 | saint-francois
# Processing Record 31 of Set 13 | balkanabat
# Processing Record 32 of Set 13 | broome
# Processing Record 33 of Set 13 | kinablangan
# Processing Record 34 of Set 13 | inuvik
# Processing Record 35 of Set 13 | bom sucesso
# Processing Record 36 of Set 13 | tomatlan
# Processing Record 37 of Set 13 | snasa
# Processing Record 38 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 39 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | bara
# Processing Record 41 of Set 13 | guacimo
# Processing Record 42 of Set 13 | anito
# Processing Record 43 of Set 13 | ancud
# Processing Record 44 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 13 | leshukonskoye
# Processing Record 46 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 13 | bambanglipuro
# Processing Record 48 of Set 13 | tete
# Processing Record 49 of Set 13 | xichang
# Processing Record 50 of Set 13 | matara
# Processing Record 1 of Set 14 | morondava
# Processing Record 2 of Set 14 | guarumal
# Processing Record 3 of Set 14 | novikovo
# Processing Record 4 of Set 14 | gorbatovka
# Processing Record 5 of Set 14 | aras
# Processing Record 6 of Set 14 | portland
# Processing Record 7 of Set 14 | chokwe
# Processing Record 8 of Set 14 | chhukha
# City not found. Skipping...
# Processing Record 9 of Set 14 | vila do maio
# Processing Record 10 of Set 14 | brookings
# Processing Record 11 of Set 14 | weyburn
# Processing Record 12 of Set 14 | kungsbacka
# Processing Record 13 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 14 | tromso
# Processing Record 15 of Set 14 | sakaiminato
# Processing Record 16 of Set 14 | hirara
# Processing Record 17 of Set 14 | mount darwin
# Processing Record 18 of Set 14 | san isidro
# Processing Record 19 of Set 14 | vetluzhskiy
# Processing Record 20 of Set 14 | iguape
# Processing Record 21 of Set 14 | xining
# Processing Record 22 of Set 14 | karimpur
# Processing Record 23 of Set 14 | emerald
# Processing Record 24 of Set 14 | griffith
# Processing Record 25 of Set 14 | kurumkan
# Processing Record 26 of Set 14 | inyonga
# Processing Record 27 of Set 14 | neyshabur
# Processing Record 28 of Set 14 | hornepayne
# Processing Record 29 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 14 | atlantic beach
# Processing Record 31 of Set 14 | kattivakkam
# Processing Record 32 of Set 14 | college
# Processing Record 33 of Set 14 | whitehorse
# Processing Record 34 of Set 14 | ewa beach
# Processing Record 35 of Set 14 | bogale
# Processing Record 36 of Set 14 | puruaran
# Processing Record 37 of Set 14 | krasnoyarskiy
# Processing Record 38 of Set 14 | salinas
# Processing Record 39 of Set 14 | kalispell
# Processing Record 40 of Set 14 | jackson
# Processing Record 41 of Set 14 | kamiiso
# Processing Record 42 of Set 14 | chany
# Processing Record 43 of Set 14 | vrangel
# Processing Record 44 of Set 14 | vikindu
# Processing Record 45 of Set 14 | nemuro
# Processing Record 46 of Set 14 | hermosillo
# Processing Record 47 of Set 14 | yeniseysk
# Processing Record 48 of Set 14 | oksfjord
# Processing Record 49 of Set 14 | martapura
# Processing Record 50 of Set 14 | okara
# Processing Record 1 of Set 15 | san blas
# Processing Record 2 of Set 15 | baykit
# Processing Record 3 of Set 15 | omaruru
# Processing Record 4 of Set 15 | kolaras
# Processing Record 5 of Set 15 | seoul
# Processing Record 6 of Set 15 | pokhara
# Processing Record 7 of Set 15 | tara
# Processing Record 8 of Set 15 | kungurtug
# Processing Record 9 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 15 | tashtyp
# Processing Record 11 of Set 15 | berlevag
# Processing Record 12 of Set 15 | batouri
# Processing Record 13 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 15 | taguatinga
# Processing Record 15 of Set 15 | chaman
# Processing Record 16 of Set 15 | denpasar
# Processing Record 17 of Set 15 | jadu
# Processing Record 18 of Set 15 | alenquer
# Processing Record 19 of Set 15 | areosa
# Processing Record 20 of Set 15 | chapais
# Processing Record 21 of Set 15 | suluq
# Processing Record 22 of Set 15 | dhadar
# Processing Record 23 of Set 15 | weligama
# Processing Record 24 of Set 15 | lebanon
# Processing Record 25 of Set 15 | yakeshi
# Processing Record 26 of Set 15 | novyy starodub
# Processing Record 27 of Set 15 | smithers
# Processing Record 28 of Set 15 | carutapera
# Processing Record 29 of Set 15 | evansville
# Processing Record 30 of Set 15 | tembisa
# Processing Record 31 of Set 15 | livingstone
# Processing Record 32 of Set 15 | kiruna
# Processing Record 33 of Set 15 | tilichiki
# Processing Record 34 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 15 | kedougou
# Processing Record 36 of Set 15 | soe
# Processing Record 37 of Set 15 | fukue
# Processing Record 38 of Set 15 | fairbanks
# Processing Record 39 of Set 15 | kohlu
# Processing Record 40 of Set 15 | kenai
# Processing Record 41 of Set 15 | tessalit
# Processing Record 42 of Set 15 | santa fe
# Processing Record 43 of Set 15 | ballina
# Processing Record 44 of Set 15 | promysla
# City not found. Skipping...
# Processing Record 45 of Set 15 | arona
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# [{'City': 'novyy urengoy', 'Country': 'RU', 'Date': '2022-12-22 16:38:41', 'Lat': 66.0833, 'Lng': 76.6333, 'Max Temp': -9.47, 'Humidity': 93, 'Cloudiness': 38, 'Wind Speed': 9.84, 'Current Description': 'scattered clouds', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'kapaa', 'Country': 'US', 'Date': '2022-12-22 16:37:41', 'Lat': 22.0752, 'Lng': -159.319, 'Max Temp': 71.58, 'Humidity': 88, 'Cloudiness': 0, 'Wind Speed': 5.75, 'Current Description': 'light rain', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'avarua', 'Country': 'CK', 'Date': '2022-12-22 16:38:05', 'Lat': -21.2078, 'Lng': -159.775, 'Max Temp': 77.05, 'Humidity': 88, 'Cloudiness': 75, 'Wind Speed': 6.91, 'Current Description': 'broken clouds', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'araouane', 'Country': 'ML', 'Date': '2022-12-22 16:38:42', 'Lat': 18.9048, 'Lng': -3.5265, 'Max Temp': 75.72, 'Humidity': 17, 'Cloudiness': 94, 'Wind Speed': 11.23, 'Current Description': 'overcast clouds', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'nisia floresta', 'Country': 'BR', 'Date': '2022-12-22 16:38:42', 'Lat': -6.0911, 'Lng': -35.2086, 'Max Temp': 85.01, 'Humidity': 50, 'Cloudiness': 81, 'Wind Speed': 12.35, 'Current Description': 'light rain', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'jamestown', 'Country': 'US', 'Date': '2022-12-22 16:36:51', 'Lat': 42.097, 'Lng': -79.2353, 'Max Temp': 38.79, 'Humidity': 63, 'Cloudiness': 100, 'Wind Speed': 9.22, 'Current Description': 'overcast clouds', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'barrow', 'Country': 'US', 'Date': '2022-12-22 16:34:01', 'Lat': 71.2906, 'Lng': -156.7887, 'Max Temp': 15.82, 'Humidity': 86, 'Cloudiness': 100, 'Wind Speed': 9.22, 'Current Description': 'overcast clouds', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'codrington', 'Country': 'AU', 'Date': '2022-12-22 16:38:43', 'Lat': -38.2667, 'Lng': 141.9667, 'Max Temp': 55.69, 'Humidity': 95, 'Cloudiness': 1, 'Wind Speed': 4.34, 'Current Description': 'clear sky', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'ushuaia', 'Country': 'AR', 'Date': '2022-12-22 16:36:45', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 60.46, 'Humidity': 63, 'Cloudiness': 0, 'Wind Speed': 5.75, 'Current Description': 'clear sky', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'saint george', 'Country': 'US', 'Date': '2022-12-22 16:37:27', 'Lat': 37.1041, 'Lng': -113.5841, 'Max Temp': 28.99, 'Humidity': 80, 'Cloudiness': 0, 'Wind Speed': 0, 'Current Description': 'clear sky', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'cape town', 'Country': 'ZA', 'Date': '2022-12-22 16:36:57', 'Lat': -33.9258, 'Lng': 18.4232, 'Max Temp': 75.9, 'Humidity': 62, 'Cloudiness': 0, 'Wind Speed': 13.8, 'Current Description': 'clear sky', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'pevek', 'Country': 'RU', 'Date': '2022-12-22 16:38:07', 'Lat': 69.7008, 'Lng': 170.3133, 'Max Temp': -0.31, 'Humidity': 78, 'Cloudiness': 0, 'Wind Speed': 2.64, 'Current Description': 'clear sky', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'bathsheba', 'Country': 'BB', 'Date': '2022-12-22 16:38:44', 'Lat': 13.2167, 'Lng': -59.5167, 'Max Temp': 86.61, 'Humidity': 77, 'Cloudiness': 20, 'Wind Speed': 24.16, 'Current Description': 'few clouds', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'vao', 'Country': 'NC', 'Date': '2022-12-22 16:37:43', 'Lat': -22.6667, 'Lng': 167.4833, 'Max Temp': 78.28, 'Humidity': 77, 'Cloudiness': 17, 'Wind Speed': 10.65, 'Current Description': 'moderate rain', 'Rain inches (last 3 hrs)': 0.0, 'Snow inches (last 3 hrs)': 0}, {'City': 'albany', 'Country': 'US', 'Date': '2022-12-22 16:35:04', 'Lat': 42.6001, 'Lng': -73.9662, 'M ...

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0   novyy urengoy      RU  2022-12-22 16:38:41  66.0833   76.6333     -9.47
# 1           kapaa      US  2022-12-22 16:37:41  22.0752 -159.3190     71.58
# 2          avarua      CK  2022-12-22 16:38:05 -21.2078 -159.7750     77.05
# 3        araouane      ML  2022-12-22 16:38:42  18.9048   -3.5265     75.72
# 4  nisia floresta      BR  2022-12-22 16:38:42  -6.0911  -35.2086     85.01
# 5       jamestown      US  2022-12-22 16:36:51  42.0970  -79.2353     38.79
# 6          barrow      US  2022-12-22 16:34:01  71.2906 -156.7887     15.82
# 7      codrington      AU  2022-12-22 16:38:43 -38.2667  141.9667     55.69
# 8         ushuaia      AR  2022-12-22 16:36:45 -54.8000  -68.3000     60.46
# 9    saint george      US  2022-12-22 16:37:27  37.1041 -113.5841     28.99
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        93          38        9.84    scattered clouds
# 1        88           0        5.75          light rain
# 2        88          75        6.91       broken clouds
# 3        17          94       11.23     overcast clouds
# 4        50          81       12.35          light rain
# 5        63         100        9.22     overcast clouds
# 6        86         100        9.22     overcast clouds
# 7        95           1        4.34           clear sky
# 8        63           0        5.75           clear sky
# 9        80           0        0.00           clear sky
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                       0.0                         0
# 1                       0.0                         0
# 2                       0.0                         0
# 3                       0.0                         0
# 4                       0.0                         0
# 5                       0.0                         0
# 6                       0.0                         0
# 7                       0.0                         0
# 8                       0.0                         0
# 9                       0.0                         0

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Current Description',
#        'Rain inches (last 3 hrs)', 'Snow inches (last 3 hrs)'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]
# Recreate the DataFrame by using the new column or
clean_city_data_df = city_data_df

# Display sample data
# YOUR CODE HERE
clean_city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   novyy urengoy      RU  66.0833   76.6333     -9.47        93          38
# 1           kapaa      US  22.0752 -159.3190     71.58        88           0
# 2          avarua      CK -21.2078 -159.7750     77.05        88          75
# 3        araouane      ML  18.9048   -3.5265     75.72        17          94
# 4  nisia floresta      BR  -6.0911  -35.2086     85.01        50          81
#
#    Wind Speed Current Description
# 0        9.84    scattered clouds
# 1        5.75          light rain
# 2        6.91       broken clouds
# 3       11.23     overcast clouds
# 4       12.35          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
clean_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
